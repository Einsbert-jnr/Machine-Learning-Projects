# %%
# !pip install stable-baselines3[extra]

# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ### Loading the environment

# %%
# loading the environment
env_name = 'CartPole-v0'
env = gym.make(env_name, render_mode='human')

# %%
episodes = 5

for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info,_ = env.step(action)
        score += reward
    print(f"Episode: {episode} Score: {score}")
# env.close()
# Out:
# Episode: 1 Score: 36.0
# Episode: 2 Score: 14.0
# Episode: 3 Score: 22.0
# Episode: 4 Score: 13.0
# Episode: 5 Score: 30.0

# %%
env.close()

# %% [markdown]
# ### Understanding the environment

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space
# Out:
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)

# %% [markdown]
# ### Train an RL model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(env_name, render_mode='human')
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# /home/einsbert/anaconda3/lib/python3.12/site-packages/gymnasium/envs/registration.py:519: DeprecationWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.deprecation(

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 47   |
# |    iterations      | 1    |
# |    time_elapsed    | 43   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 46          |
# |    iterations           | 2           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010068495 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.00207    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.29        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 48.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 3           |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010781495 |
# |    clip_fraction        | 0.0739      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 38.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 4           |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007856863 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 52.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 5           |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010987351 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 62.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 6           |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008502518 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 54.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 7            |
# |    time_elapsed         | 301          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0074458164 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.536        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.1         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 48.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 8            |
# |    time_elapsed         | 344          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0054294993 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.564       |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.93         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00688     |
# |    value_loss           | 51.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 9            |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0057084206 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.565       |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.18         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00993     |
# |    value_loss           | 21.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 10           |
# |    time_elapsed         | 429          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0040290444 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.564       |
# |    explained_variance   | 0.758        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.87         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 15.4         |
# ------------------------------------------

# %% [markdown]
# ### Save and reload the model

# %%
PPO_Path = os.path.join('Training', 'SavedModel', 'PPO_Model_CartPole')

# %%
import gymnasium
import sys

# Monkey-patch to make gymnasium look like gym
sys.modules['gym'] = gymnasium
import gym
gym.__version__ = "26.2.0"  # Or any dummy version string

# %%
model.save(PPO_Path)

# %%
# del model
# model = PPO.load(PPO_Path, env=env)

# %% [markdown]
# ### Evaluation

# %%
eval_env = gym.make(env_name, render_mode="human")
evaluate_policy(model, eval_env, n_eval_episodes=10, render=True)
# Out:
# (200.0, 0.0)

# %%
eval_env.close()

# %% [markdown]
# ### Testing our model

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])
episodes = 5

for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action, _= model.predict(obs)
        obs, reward, done, info= env.step(action)
        score += reward
    print(f"Episode: {episode} Score: {score}")
# env.close()
# Out:
# Episode: 1 Score: [200.]
# Episode: 2 Score: [200.]
# Episode: 3 Score: [200.]
# Episode: 4 Score: [200.]
# Episode: 5 Score: [200.]

# %%
env.step(action)
# Out:
# (array([[-0.02249668, -0.43952107,  0.03527744,  0.5846608 ]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{'TimeLimit.truncated': False}])

# %% [markdown]
# ### Logging with tensorboard
# Good to do this in the command prompt since it can lock up the notebook here

# %%
training_log_path = os.path.join(log_path, 'PPO_1')

# %%
# !tensorboard --logdir={training_log_path} # in the terminal as well.
# !ls Training
# Out:
# Logs  SavedModel

# %% [markdown]
# ### Adding a callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])
save_path = os.path.join('Training', 'SavedModel')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)

eval_callback = EvalCallback(
    env, callback_on_new_best=stop_callback, eval_freq=10000,
    verbose=1, 
    best_model_save_path=save_path
)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)

model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Using cpu device
# Logging to Training/Logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 1266 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 988         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008301033 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00269     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.66        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 51.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 934         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010266361 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 31.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007269944 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 49.6        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=190.40 +/- 19.20
# Episode length: 190.40 +/- 19.20
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 190         |
# |    mean_reward          | 190         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.008320499 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.618      |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 55          |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 802   |
# |    iterations      | 5     |
# |    time_elapsed    | 12    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008783286 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 52.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008671261 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 57.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 775          |
# |    iterations           | 8            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0075839083 |
# |    clip_fraction        | 0.0861       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.635        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00934     |
# |    value_loss           | 55.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009945013 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00895    |
# |    value_loss           | 31.9        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.005839682 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.568      |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.952       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00759    |
# |    value_loss           | 14.9        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %% [markdown]
# ### changing policies

# %%
new_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch': new_arch})

model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Using cpu device
# Logging to Training/Logs/PPO_5
# /home/einsbert/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 1219 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015390305 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.00228    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.97        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 19.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015435103 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0331     |
# |    value_loss           | 28.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 4           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012493202 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 46.4        |
# -----------------------------------------
# /home/einsbert/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0155266775 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.562       |
# |    explained_variance   | 0.607        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.83         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0186      |
# |    value_loss           | 40           |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 637   |
# |    iterations      | 5     |
# |    time_elapsed    | 16    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 6           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006653837 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.69        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00586    |
# |    value_loss           | 16.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 7            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0065170247 |
# |    clip_fraction        | 0.0947       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.62         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.014       |
# |    value_loss           | 16.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 8           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010692269 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.536      |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.768       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 6.75        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 9           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010747923 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.504       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00528    |
# |    value_loss           | 3.78        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.010007108 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.735       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00696    |
# |    value_loss           | 2.6         |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 575   |
# |    iterations      | 10    |
# |    time_elapsed    | 35    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# ### Using an alternate algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)

model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Using cpu device
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4298     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1806     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 208      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.539    |
# |    n_updates        | 26       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1413     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 308      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.484    |
# |    n_updates        | 51       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.806    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1296     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 408      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.442    |
# |    n_updates        | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1205     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 476      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.385    |
# |    n_updates        | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1146     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 539      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.36     |
# |    n_updates        | 109      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.708    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1129     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 615      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.307    |
# |    n_updates        | 128      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1028     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 720      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 886      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 794      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 173      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.571    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 778      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 903      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 772      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 966      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 216      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 775      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1013     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.093    |
# |    n_updates        | 228      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.497    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 772      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1058     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0832   |
# |    n_updates        | 239      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.477    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 775      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1101     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0749   |
# |    n_updates        | 250      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 783      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1161     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0579   |
# |    n_updates        | 265      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.424    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 789      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1212     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 277      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.404    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 790      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1254     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0441   |
# |    n_updates        | 288      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.377    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 796      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1311     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 302      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.355    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 794      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1357     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 314      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.335    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 783      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1401     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 325      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 772      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1446     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 336      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.291    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 773      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1492     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0219   |
# |    n_updates        | 347      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.271    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 768      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1535     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 358      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.245    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 766      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1589     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0288   |
# |    n_updates        | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 768      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0007   |
# |    n_updates        | 1079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 765      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4460     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00225  |
# |    n_updates        | 1089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 765      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4502     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000498 |
# |    n_updates        | 1100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 766      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4546     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000539 |
# |    n_updates        | 1111     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 766      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4587     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000614 |
# |    n_updates        | 1121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 767      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4626     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000645 |
# |    n_updates        | 1131     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 768      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4668     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000548 |
# |    n_updates        | 1141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 769      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4710     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000496 |
# |    n_updates        | 1152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 770      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4751     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000351 |
# |    n_updates        | 1162     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 768      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4793     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000763 |
# |    n_updates        | 1173     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 766      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4837     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000719 |
# |    n_updates        | 1184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 768      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4881     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0005   |
# |    n_updates        | 1195     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 769      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4925     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000503 |
# |    n_updates        | 1206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 769      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 4967     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000602 |
# |    n_updates        | 1216     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 770      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5008     |
# | train/              |          |
# ...
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 660      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 18264    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 4540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 660      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 18324    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0274   |
# |    n_updates        | 4555     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 660      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 18371    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 4567     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 660      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 18410    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0475   |
# |    n_updates        | 4577     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1408     |
# |    fps              | 660      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 18483    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0433   |
# |    n_updates        | 4595     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 659      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18564    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 4615     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1416     |
# |    fps              | 656      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18618    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 4629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 656      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18656    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 4638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1424     |
# |    fps              | 656      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18693    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0069   |
# |    n_updates        | 4648     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1428     |
# |    fps              | 655      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18736    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 4658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1432     |
# |    fps              | 655      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18776    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 4668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 655      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18815    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 4678     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 655      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18856    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 4688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1444     |
# |    fps              | 655      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18931    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 4707     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 655      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18965    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 4716     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1452     |
# |    fps              | 655      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 19004    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 4725     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1456     |
# |    fps              | 655      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19083    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 4745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 655      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19132    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0354   |
# |    n_updates        | 4757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1464     |
# |    fps              | 655      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19171    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0501   |
# |    n_updates        | 4767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1468     |
# |    fps              | 652      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19210    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 4777     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1472     |
# |    fps              | 650      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19263    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 4790     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1476     |
# |    fps              | 650      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19303    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0405   |
# |    n_updates        | 4800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1480     |
# |    fps              | 650      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19345    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 4811     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1484     |
# |    fps              | 650      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19385    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 4821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1488     |
# |    fps              | 650      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19468    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0411   |
# |    n_updates        | 4841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1492     |
# |    fps              | 650      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 19508    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00392  |
# |    n_updates        | 4851     |
# ----------------------------------
# Eval num_timesteps=19520, episode_reward=12.80 +/- 7.63
# Episode length: 12.80 +/- 7.63
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 12.8     |
# |    mean_reward      | 12.8     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 19520    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 4854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1496     |
# |    fps              | 649      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 19547    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 4861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 648      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 19598    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 4874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1504     |
# |    fps              | 648      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 19633    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 4883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1508     |
# |    fps              | 648      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 19673    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.044    |
# |    n_updates        | 4893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1512     |
# |    fps              | 647      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 19722    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 4905     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1516     |
# |    fps              | 645      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 19795    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 4923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1520     |
# |    fps              | 644      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 19855    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 4938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1524     |
# |    fps              | 641      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 19944    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 4960     |
# ----------------------------------
